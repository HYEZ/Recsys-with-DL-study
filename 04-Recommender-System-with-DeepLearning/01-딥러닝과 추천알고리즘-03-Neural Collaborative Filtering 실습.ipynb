# %% [markdown]
# # Neural Collaborative Filtering
# 1. [논문](https://arxiv.org/pdf/1708.05031.pdf)
# 2. Keras로 작성된 [저자 코드](https://github.com/hexiangnan/neural_collaborative_filtering)
# 3. 논문은 0과 1로 user-item interaction으로 matrix을 나타내고 학습했으나, 이번 실습에서는 rating을 직접 예측하고, loss를 구해보는 것을 진행한다

# %% [markdown]
# ## Configuration

# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

import math
from torch import nn, optim
import torch
import torch.nn.functional as F
from torch.autograd import Variable

from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Dataset
# - KMRD 데이터셋 활용
# - google colab의 경우 data path 다시 확인하기

# %%
data_path = '../data/kmrd/kmr_dataset/datafile/kmrd-small'

# %%
def read_data(data_path):
    df = pd.read_csv(os.path.join(data_path,'rates.csv'))
    train_df, val_df = train_test_split(df, test_size=0.2, random_state=1234, shuffle=True)
    return train_df, val_df

# %%
# 학습할 영화 데이터 분석
train_df, val_df = read_data(data_path)

# %%
print(train_df)
print(val_df)
# Out:
#          user  movie  rate        time
# 137023  48423  10764    10  1212241560
# 92868   17307  10170    10  1122185220
# 94390   18180  10048    10  1573403460
# 22289    1498  10001     9  1432684500
# 80155   12541  10022    10  1370458140
# ...       ...    ...   ...         ...
# 41239    3770  10105     8  1071500400
# 55985    6231  10115    10  1471905960
# 32399    2689  10002     8  1177868460
# 82584   13301  10037     9  1510613160
# 121909  35441  10200    10  1110351360
#
# [112568 rows x 4 columns]
#          user  movie  rate        time
# 76196   11242  10253    10  1437788760
# 109800  26903  10102    10  1322643900
# 60479    7101  10007     1  1314804000
# 71460    9705  10016    10  1228825200
# 73864   10616  10106     8  1425046200
# ...       ...    ...   ...         ...
# 64944    7768  10099     9  1239756840
# 20618    1351  10110    10  1095570120
# 118034  32430  10153     4  1169823660
# 69366    8967  10936    10  1230170340
# 117770  32228  10153     1  1336670820
#
# [28142 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(12, 7))
ax = ax.ravel()

train_df['rate'].hist(ax=ax[0])
val_df['rate'].hist(ax=ax[1])
# Out:
# <AxesSubplot:>

# %%
train_df['rate'].describe()
# Out:
# count    112568.000000
# mean          8.948369
# std           2.114602
# min           1.000000
# 25%           9.000000
# 50%          10.000000
# 75%          10.000000
# max          10.000000
# Name: rate, dtype: float64

# %% [markdown]
# ## Load movie dataframe

# %%
# Load all related dataframe
movies_df = pd.read_csv(os.path.join(data_path, 'movies.txt'), sep='\t', encoding='utf-8')
movies_df = movies_df.set_index('movie')

castings_df = pd.read_csv(os.path.join(data_path, 'castings.csv'), encoding='utf-8')
countries_df = pd.read_csv(os.path.join(data_path, 'countries.csv'), encoding='utf-8')
genres_df = pd.read_csv(os.path.join(data_path, 'genres.csv'), encoding='utf-8')

# Get genre information
genres = [(list(set(x['movie'].values))[0], '/'.join(x['genre'].values)) for index, x in genres_df.groupby('movie')]
combined_genres_df = pd.DataFrame(data=genres, columns=['movie', 'genres'])
combined_genres_df = combined_genres_df.set_index('movie')


# Get castings information
castings = [(list(set(x['movie'].values))[0], x['people'].values) for index, x in castings_df.groupby('movie')]
combined_castings_df = pd.DataFrame(data=castings, columns=['movie','people'])
combined_castings_df = combined_castings_df.set_index('movie')

# Get countries for movie information
countries = [(list(set(x['movie'].values))[0], ','.join(x['country'].values)) for index, x in countries_df.groupby('movie')]
combined_countries_df = pd.DataFrame(data=countries, columns=['movie', 'country'])
combined_countries_df = combined_countries_df.set_index('movie')

movies_df = pd.concat([movies_df, combined_genres_df, combined_castings_df, combined_countries_df], axis=1)

# %%
movies_df.head()
# Out:
#                       title                           title_eng    year  \
# movie
# 10001                시네마 천국              Cinema Paradiso , 1988  2013.0
# 10002              빽 투 더 퓨쳐           Back To The Future , 1985  2015.0
# 10003            빽 투 더 퓨쳐 2    Back To The Future Part 2 , 1989  2015.0
# 10004            빽 투 더 퓨쳐 3  Back To The Future Part III , 1990  1990.0
# 10005  스타워즈 에피소드 4 - 새로운 희망                    Star Wars , 1977  1997.0
#
#          grade         genres  \
# movie
# 10001   전체 관람가     드라마/멜로/로맨스
# 10002  12세 관람가         SF/코미디
# 10003  12세 관람가         SF/코미디
# 10004   전체 관람가  서부/SF/판타지/코미디
# 10005       PG   판타지/모험/SF/액션
#
#                                                   people   country
# movie
# 10001  [4374, 178, 3241, 47952, 47953, 19538, 18991, ...  이탈리아,프랑스
# 10002    [1076, 4603, 917, 8637, 5104, 9986, 7470, 9987]        미국
# 10003  [1076, 4603, 917, 5104, 391, 5106, 5105, 5107,...        미국
# 10004  [1076, 4603, 1031, 5104, 10001, 5984, 10002, 1...        미국
# 10005                         [1007, 535, 215, 1236, 35]        미국

# %% [markdown]
# - 논문:  user latent vector + item latent vector
# - 새롭게 생각할 수 있는 방법: user latent vector + item latent vector + etc vector (예시) meta information

# %%
# 영화 데이터의 메타 정보를 확인한다
movieName_dict = movies_df.to_dict()['title']
genres_dict = movies_df.to_dict()['genres']

# %%
genres_dict
# Out:
# {10001: '드라마/멜로/로맨스',
#  10002: 'SF/코미디',
#  10003: 'SF/코미디',
#  10004: '서부/SF/판타지/코미디',
#  10005: '판타지/모험/SF/액션',
#  10006: '판타지/모험/SF/액션',
#  10007: '판타지/SF/액션/모험',
#  10008: 'SF/액션/모험/가족',
#  10009: '판타지/SF/액션/모험',
#  10010: '액션/코미디/판타지/SF/모험',
#  10011: 'SF/액션/모험/가족',
#  10012: '액션/스릴러/범죄',
#  10013: '멜로/로맨스/판타지/SF/모험/가족/스릴러/공포',
#  10014: '드라마/전쟁',
#  10015: '드라마/액션/스릴러',
#  10016: '코미디/가족/모험/범죄',
#  10017: '드라마/서부',
#  10018: '판타지/SF/모험/가족',
#  10019: '드라마/서부/범죄',
#  10020: '멜로/로맨스/드라마/전쟁',
#  10021: '드라마/액션',
#  10022: '드라마/액션',
#  10023: '드라마/액션',
#  10024: '드라마/액션',
#  10025: '드라마/액션',
#  10026: '액션/스릴러/범죄',
#  10027: '액션/코미디/범죄',
#  10028: 'SF/액션/스릴러',
#  10029: '스릴러/공포',
#  10030: '모험/스릴러/공포',
#  10031: '스릴러/공포',
#  10032: '스릴러/공포',
#  10033: '액션/모험',
#  10034: '판타지/액션/모험',
#  10035: '판타지/액션/모험',
#  10036: '액션',
#  10037: 'SF/공포',
#  10038: 'SF/액션/스릴러/공포',
#  10039: '드라마/전쟁',
#  10040: '코미디/스릴러/모험/가족',
#  10041: '드라마/액션/모험',
#  10042: '드라마/모험/전쟁',
#  10043: '드라마/액션/스릴러/전쟁',
#  10044: '액션/전쟁',
#  10045: '드라마/전쟁',
#  10046: '드라마/모험/범죄',
#  10047: '드라마/코미디/범죄',
#  10048: '드라마',
#  10049: '판타지/액션/코미디/공포',
#  10050: '스릴러/공포/미스터리',
#  10051: '스릴러/공포',
#  10052: '스릴러/공포',
#  10053: '드라마',
#  10054: '드라마',
#  10055: '드라마/액션/스릴러',
#  10056: '액션/전쟁',
#  10057: '액션/전쟁',
#  10058: '멜로/로맨스/드라마/액션/모험',
#  10059: '멜로/로맨스/드라마',
#  10060: '드라마',
#  10061: 'SF/액션/스릴러/공포',
#  10062: 'SF/액션/스릴러',
#  10063: '드라마',
#  10064: '드라마',
#  10065: '공포',
#  10066: '스릴러/공포/미스터리',
#  10067: '멜로/로맨스/드라마',
#  10068: '드라마/스릴러/범죄',
#  10069: '서부',
#  10070: '서부/스릴러/액션',
#  10071: '드라마/스릴러/범죄',
#  10072: '드라마/범죄',
#  10073: '멜로/로맨스/드라마',
#  10074: 'SF/액션/모험/미스터리',
#  10075: 'SF/모험',
#  10076: 'SF/모험',
#  10077: 'SF/모험',
#  10078: 'SF/모험',
#  10079: 'SF/모험',
#  10080: '코미디/범죄',
#  10081: '코미디',
#  10082: '코미디',
#  10083: '코미디',
#  10084: '코미디',
#  10085: '코미디',
#  10086: '드라마',
#  10087: '멜로/로맨스/드라마/뮤지컬',
#  10088: '모험/스릴러',
#  10089: '멜로/로맨스/뮤지컬/드라마',
#  10090: '드라마',
#  10091: '드라마/범죄',
#  10092: '판타지/모험/가족',
#  10093: '멜로/로맨스/드라마',
#  10094: '드라마/가족',
#  10095: '판타지/SF/코미디',
#  10096: '판타지/SF/코미디',
#  10097: '드라마/코미디/전쟁',
#  10098: '멜로/로맨스/뮤지컬',
#  10099: '멜로/로맨스/드라마',
#  10100: '드라마/액션',
#  10101: '멜로/로맨스/드라마/코미디',
#  10102: '멜로/로맨스/뮤지컬/드라마',
#  10103: '멜로/로맨스/드라마/전쟁',
#  10104: '멜로/로맨스/드라마',
#  10105: '멜로/로맨스/뮤지컬/코미디',
#  10106: '멜로/로맨스/드라마',
#  10107: '드라마',
#  10108: '멜로/로맨스/뮤지컬',
#  10109: '액션',
#  10110: '드라마/느와르/액션/범죄',
#  10111: '드라마/느와르/액션/범죄',
#  10112: '드라마/느와르/액션/범죄',
#  10113: '드라마/액션/스릴러/범죄',
#  10114: '드라마',
#  10115: '액션/모험/코미디',
#  10116: '판타지/멜로/로맨스/코미디',
#  10117: '멜로/로맨스/드라마/코미디',
#  10118: '멜로/로맨스/드라마/코미디',
#  10119: 'SF/공포',
#  10120: nan,
#  10121: '서부/코미디',
#  10122: '드라마/미스터리/스릴러/범죄',
#  10123: '서부/코미디',
#  10124: '멜로/로맨스/코미디',
#  10125: 'SF/멜로/로맨스/코미디',
#  10126: '코미디/공포',
#  10127: '드라마/뮤지컬',
#  10128: '드라마/전쟁',
#  10129: '코미디',
#  10130: '드라마/스릴러/범죄',
#  10131: '액션/코미디',
#  10132: '멜로/로맨스/코미디',
#  10133: '드라마',
#  10134: nan,
#  10135: '스릴러/미스터리/범죄',
#  10136: '드라마',
#  10137: '판타지/스릴러/공포',
#  10138: '드라마',
#  10139: nan,
#  10140: 'SF/액션',
#  10141: 'SF/액션',
#  10142: 'SF/액션/모험',
#  10143: '드라마/멜로/로맨스/코미디',
#  10144: '멜로/로맨스/드라마',
#  10145: '드라마/스릴러/범죄',
#  10146: '멜로/로맨스/드라마',
#  10147: '드라마/모험',
#  10148: nan,
#  10149: '판타지/스릴러/공포',
#  10150: '멜로/로맨스/드라마/모험/코미디',
#  10151: '드라마',
#  10152: '드라마',
#  10153: '애니메이션/액션/코미디/SF/가족',
#  10154: '멜로/로맨스/드라마',
#  10155: '액션/스릴러',
#  10156: '모험/액션/스릴러',
#  10157: '모험/액션/스릴러',
#  10158: '액션/모험',
#  10159: '액션/모험/스릴러',
#  10160: '액션/모험/코미디',
#  10161: '멜로/로맨스/액션/모험/스릴러',
#  10162: '액션/모험',
#  10163: '액션/모험',
#  10164: '액션',
#  10165: '액션/스릴러',
#  10166: 'SF/액션',
#  10167: '액션/스릴러',
#  10168: '액션/모험',
#  10169: '액션',
#  10170: '액션',
#  10171: '액션/모험/스릴러',
#  10172: '액션/모험',
#  10173: '멜로/로맨스/드라마',
#  10174: '뮤지컬',
#  10175: '멜로/로맨스/드라마',
#  10176: '드라마',
#  10177: '멜로/로맨스/드라마/서부/전쟁',
#  10178: '스릴러/공포',
#  10179: '서부/스릴러',
#  10180: '스릴러',
#  10181: '멜로/로맨스/드라마/액션',
#  10182: '액션/범죄',
#  10183: '액션/코미디/범죄',
#  10184: '액션',
#  10185: '멜로/로맨스/드라마',
#  10186: '액션/코미디',
#  10187: '공포',
#  10188: '공포',
#  10189: '공포',
#  10190: '판타지/액션/모험',
#  10191: '판타지/액션/모험',
#  10192: nan,
#  10193: '액션',
#  10194: '액션',
#  10195: '액션',
#  10196: '액션',
#  10197: '액션',
#  10198: '액션',
#  10199: '멜로/로맨스/드라마',
#  10200: 'SF/액션/스릴러',
#  10201: '드라마',
#  10202: '드라마',
#  10203: '느와르/액션/범죄',
#  10204: '드라마',
#  10205: 'SF/드라마',
#  10206: '코미디/전쟁',
#  10207: '드라마',
#  10208: '드라마',
#  10209: '멜로/로맨스/액션/모험',
#  10210: '액션/모험',
#  10211: '액션/모험/코미디/범죄',
#  10212: '멜로/로맨스/드라마/모험/전쟁',
#  10213: '드라마',
#  10214: '액션/코미디',
#  10215: '드라마',
#  10216: '코미디/액션/스릴러/범죄',
#  10217: 'SF/액션/범죄',
#  10218: 'SF/액션/스릴러/범죄',
#  10219: '코미디',
#  10220: '코미디/범죄',
#  10221: '미스터리/코미디/범죄',
#  10222: '코미디/범죄',
#  10223: '코미디/범죄',
#  10224: '코미디/범죄',
#  10225: '코미디/범죄',
#  10226: '코미디/범죄',
#  10227: '코미디/범죄',
#  10228: '판타지/드라마/공포',
#  10229: '드라마/뮤지컬/코미디',
#  10230: '드라마/코미디',
#  10231: '코미디/범죄',
#  10232: 'SF/드라마',
#  10233: '전쟁',
#  10234: '공포',
#  10235: '멜로/로맨스/뮤지컬/전쟁',
#  10236: '멜로/로맨스/액션',
#  10237: '코미디',
#  10238: '드라마',
#  10239: '멜로/로맨스/드라마',
#  10240: '드라마',
#  10241: '드라마',
#  10242: '멜로/로맨스/드라마',
#  10243: '멜로/로맨스/모험/스릴러',
#  10244: '드라마/서부/모험',
#  10245: '액션',
#  10246: '액션/미스터리/SF/스릴러/공포',
#  10247: '드라마/액션/코미디',
#  10248: '멜로/로맨스/서부/드라마',
#  10249: '코미디',
#  10250: '멜로/로맨스/코미디',
#  10251: 'SF/드라마/모험',
#  10252: '액션/판타지/SF/가족/범죄',
#  10253: '액션/스릴러/범죄',
#  10254: '드라마/코미디',
#  10255: '드라마/공포',
#  10256: '드라마/공포',
#  10257: '드라마/공포',
#  10258: '드라마',
#  10259: '드라마/가족',
#  10260: '드라마/액션/모험/가족',
#  10261: '드라마/액션/가족',
#  10262: '드라마',
#  10263: '서부/모험',
#  10264: '드라마/미스터리/스릴러',
#  10265: '드라마/미스터리/스릴러',
#  10266: nan,
#  10267: '드라마/액션/스릴러',
#  10268: '코미디',
#  10269: '판타지/드라마/코미디/SF',
#  10270: '판타지/멜로/로맨스/코미디',
#  10271: '멜로/로맨스/드라마',
#  10272: '드라마',
#  10273: '판타지/코미디',
#  10274: 'SF/코미디',
#  10275: '드라마/액션/범죄',
#  10276: '드라마/미스터리',
#  10277: '스릴러/코미디/공포',
#  10278: '드라마',
#  10279: '드라마/전쟁',
#  10280: '공포',
#  10281: '스릴러/범죄',
#  10282: '드라마/모험',
#  10283: '드라마',
#  10284: '드라마',
#  10285: '판타지/드라마/뮤지컬',
#  10286: '코미디',
#  10287: '멜로/로맨스/액션/코미디/모험/가족',
#  10288: '멜로/로맨스/드라마/전쟁',
#  10289: '드라마/범죄',
#  10290: '액션/코미디',
#  10291: '액션/코미디',
#  10292: '코미디',
#  10293: '드라마',
#  10294: 'SF/드라마',
#  10295: '드라마/스릴러/범죄',
#  10296: '드라마/전쟁',
#  10297: '드라마/서부',
#  10298: '액션',
#  10299: '멜로/로맨스/코미디',
#  10300: '드라마',
#  10301: '멜로/로맨스/드라마/코미디',
#  10302: '코미디',
#  10303: 'SF/공포',
#  10304: 'SF/액션/스릴러/공포',
#  10305: '드라마/액션',
#  10306: '액션/코미디',
#  10307: '액션',
#  10308: '판타지/드라마/공포',
#  10309: '멜로/로맨스/드라마',
#  10310: '멜로/로맨스/코미디',
#  10311: '멜로/로맨스/드라마',
#  10312: '범죄',
#  10313: '드라마/스릴러/범죄',
#  10314: '드라마/서사',
#  10315: '멜로/로맨스/드라마',
#  10316: '드라마/스릴러/미스터리/범죄',
#  10317: '드라마/전쟁',
#  10318: '드라마',
#  10319: '드라마/범죄',
#  10320: '드라마',
#  10321: '드라마/코미디',
#  10322: '드라마',
#  10323: '멜로/로맨스/드라마/뮤지컬',
#  10324: '드라마/스릴러',
#  10325: '코미디',
#  10326: '멜로/로맨스/코미디',
#  10327: nan,
#  10328: '드라마/서부/모험',
#  10329: '드라마/범죄',
#  10330: '드라마/액션/범죄',
#  10331: '멜로/로맨스/드라마',
#  10332: '드라마/액션',
#  10333: '드라마/액션/전쟁',
#  10334: '드라마/전쟁',
#  10335: '서부',
#  10336: '드라마',
#  10337: '멜로/로맨스/드라마',
#  10338: '드라마/전쟁',
#  10339: '코미디',
#  10340: '멜로/로맨스/드라마/코미디',
#  10341: '코미디',
#  10342: '드라마/전쟁',
#  10343: '멜로/로맨스/드라마/스릴러/미스터리',
#  10344: '느와르/미스터리',
#  10345: '서부',
#  10346: '멜로/로맨스/드라마',
#  10347: '드라마/스릴러',
#  10348: '드라마/스릴러/범죄',
#  10349: '드라마/서부/모험',
#  10350: '드라마',
#  10351: '스릴러/미스터리/범죄',
#  10352: '코미디/가족',
#  10353: '드라마',
#  10354: nan,
#  10355: '액션/미스터리/코미디',
#  10356: '드라마',
#  10357: '멜로/로맨스/모험/코미디',
#  10358: '멜로/로맨스/코미디',
#  10359: '드라마',
#  10360: '드라마',
#  10361: '드라마/전쟁',
#  10362: '액션',
#  10363: '멜로/로맨스/뮤지컬/코미디',
#  10364: '드라마/서부/전쟁',
#  10365: '드라마/액션/전쟁',
#  10366: '드라마/액션/스릴러',
#  10367: '미스터리/스릴러',
#  10368: '드라마',
#  10369: nan,
#  10370: '코미디',
#  10371: '드라마',
#  10372: nan,
#  10373: '드라마',
#  10374: '멜로/로맨스/드라마/뮤지컬',
#  10375: '드라마/공포',
#  10376: '드라마/스릴러/공포',
#  10377: '공포',
#  10378: '드라마/전쟁',
#  10379: '스릴러',
#  10380: '드라마',
#  10381: '드라마',
#  10382: '액션',
#  10383: '멜로/로맨스/드라마/액션/스릴러',
#  10384: '드라마',
#  10385: '멜로/로맨스/드라마/범죄',
#  10386: '멜로/로맨스/드라마',
#  10387: nan,
#  10388: '멜로/로맨스/코미디',
#  10389: '드라마/전쟁',
#  10390: '모험/코미디',
#  10391: '액션/모험/코미디',
#  10392: '액션/모험/코미디',
#  10393: nan,
#  10394: '드라마',
#  10395: '멜로/로맨스/드라마/뮤지컬',
#  10396: '미스터리/판타지/SF/모험/가족/스릴러',
#  10397: '드라마/전쟁',
#  10398: '드라마',
#  10399: '액션/스릴러/범죄',
#  10400: '판타지/모험/스릴러/공포',
#  10401: '액션/코미디',
#  10402: '액션/코미디',
#  10403: '드라마/코미디',
#  10404: '드라마',
#  10405: '드라마/코미디',
#  10406: '드라마',
#  10407: '드라마',
#  10408: '미스터리',
#  10409: '드라마',
#  10410: '드라마/코미디',
#  10411: '미스터리/SF/모험/스릴러/공포',
#  10412: '판타지/멜로/로맨스/모험',
#  10413: '모험/가족',
#  10414: '드라마',
#  10415: '뮤지컬',
#  10416: '드라마/뮤지컬/코미디',
#  10417: '코미디/에로',
#  10418: '드라마',
#  10419: '드라마/에로',
#  10420: '드라마/액션',
#  10421: '드라마',
#  10422: '드라마',
#  10423: '드라마',
#  10424: '멜로/로맨스/드라마',
#  10425: '드라마',
#  10426: nan,
#  10427: '드라마/가족',
#  10428: '드라마',
#  10429: '드라마/공포',
#  10430: '서부/모험',
#  10431: '드라마/액션/전쟁',
#  10432: '드라마',
#  10433: '드라마/전쟁',
#  10434: '멜로/로맨스/드라마',
#  10435: '액션',
#  10436: '드라마',
#  10437: '스릴러/미스터리/코미디/범죄',
#  10438: '공포',
#  10439: 'SF/액션/드라마',
#  10440: '액션/코미디',
#  10441: '드라마/액션',
#  10442: '드라마/모험/전쟁',
#  10443: '액션/스릴러/범죄',
#  10444: '드라마/코미디/전쟁',
#  10445: nan,
#  10446: '드라마/스릴러/범죄',
#  10447: '드라마/스릴러/범죄',
#  10448: '판타지/뮤지컬/모험/가족',
#  10449: '멜로/로맨스/드라마/전쟁',
#  10450: '코미디',
#  10451: '코미디',
#  10452: '판타지/느와르/스릴러/드라마',
#  10453: '드라마/코미디',
#  10454: '멜로/로맨스/드라마',
#  10455: '드라마',
#  10456: '드라마',
#  10457: '멜로/로맨스/드라마',
#  10458: '코미디/액션/범죄',
#  10459: 'SF/액션/스릴러',
#  10460: '드라마',
#  10461: '드라마',
#  10462: '드라마/뮤지컬/가족',
#  10463: '드라마/서부',
#  10464: '코미디/범죄',
#  10465: '드라마/스릴러/범죄',
#  10466: '멜로/로맨스/드라마',
#  10467: '드라마',
#  10468: '드라마',
#  10469: '서부/모험',
#  10470: '드라마/전쟁',
#  10471: '드라마/스릴러',
#  10472: '코미디',
#  10473: '드라마/미스터리/스릴러/범죄',
#  10474: '멜로/로맨스/미스터리/SF/스릴러/드라마',
#  10475: nan,
#  10476: '멜로/로맨스/스릴러/코미디/범죄',
#  10477: '드라마',
#  10478: '멜로/로맨스/드라마/느와르',
#  10479: '드라마/전쟁',
#  10480: '멜로/로맨스/드라마/코미디',
#  10481: '드라마/액션',
#  10482: '멜로/로맨스/드라마',
#  10483: '드라마/액션/스릴러/범죄',
#  10484: '느와르/스릴러/드라마',
#  10485: '멜로/로맨스/드라마',
#  10486: '에로',
#  10487: '멜로/로맨스/미스터리/코미디/범죄',
#  10488: '액션/스릴러/모험/코미디',
#  10489: '드라마/스릴러/공포',
#  10490: '스릴러',
#  10491: '멜로/로맨스/코미디',
#  10492: '드라마/스릴러',
#  10493: '멜로/로맨스/뮤지컬/드라마',
#  10494: '멜로/로맨스/코미디',
#  10495: '드라마/전쟁',
#  10496: '판타지/드라마/코미디',
#  10497: '멜로/로맨스/판타지/드라마/가족',
#  10498: '코미디/가족',
#  10499: '드라마',
#  10500: nan,
#  10501: '드라마/액션/전쟁',
#  10502: '멜로/로맨스/드라마',
#  10503: '스릴러',
#  10504: '스릴러/범죄/공포',
#  10505: nan,
#  10506: 'SF',
#  10507: '드라마/전쟁',
#  10508: '멜로/로맨스/드라마',
#  10509: '드라마',
#  10510: '멜로/로맨스/드라마',
#  10511: '멜로/로맨스/코미디',
#  10512: '모험/가족',
#  10513: '드라마',
#  10514: '드라마/스릴러/범죄',
#  10515: '액션/코미디',
#  10516: '코미디',
#  10517: '드라마/범죄',
#  10518: '드라마',
#  10519: '액션/모험/스릴러',
#  10520: '멜로/로맨스/드라마/코미디',
#  10521: '드라마/액션/범죄',
#  10522: '드라마',
#  10523: '액션/모험',
#  10524: '코미디/전쟁',
#  10525: '드라마/모험',
#  10526: '드라마/스릴러/범죄',
#  10527: '멜로/로맨스/뮤지컬/코미디',
#  10528: '판타지/애니메이션/뮤지컬/가족',
#  10529: '멜로/로맨스/액션/스릴러',
#  10530: '드라마',
#  10531: '코미디',
#  10532: 'SF/코미디/공포',
#  10533: '드라마',
#  10534: '코미디',
#  10535: '공포',
#  10536: '공포',
#  10537: '드라마/액션/코미디',
#  10538: '드라마/코미디',
#  10539: '액션',
#  10540: '멜로/로맨스/드라마/코미디',
#  10541: '드라마/코미디',
#  10542: '코미디',
#  10543: '액션/스릴러',
#  10544: '드라마/범죄',
#  10545: '액션',
#  10546: '멜로/로맨스/드라마/범죄',
#  10547: '드라마/코미디',
#  10548: '드라마/스릴러/미스터리',
#  10549: '드라마/범죄',
#  10550: '드라마/액션',
#  10551: '멜로/로맨스/드라마',
#  10552: '멜로/로맨스/드라마',
#  10553: '드라마/모험',
#  10554: '드라마',
#  10555: '드라마',
#  10556: '미스터리/스릴러',
#  10557: '드라마/액션/모험/전쟁',
#  10558: nan,
#  10559: nan,
#  10560: '액션/스릴러/범죄',
#  10561: '드라마/범죄',
#  10562: '멜로/로맨스/드라마/전쟁',
#  10563: '멜로/로맨스/뮤지컬/드라마',
#  10564: '드라마',
#  10565: '드라마',
#  10566: '드라마',
#  10567: '멜로/로맨스/드라마',
#  10568: '멜로/로맨스/판타지/드라마',
#  10569: '코미디',
#  10570: '멜로/로맨스/코미디',
#  10571: 'SF/스릴러/공포',
#  10572: '멜로/로맨스/에로',
#  10573: '에로',
#  10574: '드라마',
#  10575: '멜로/로맨스/드라마/가족',
#  10576: '멜로/로맨스',
#  10577: '모험/공포',
#  10578: '멜로/로맨스/코미디/전쟁',
#  10579: '드라마/스릴러/전쟁',
#  10580: '멜로/로맨스/드라마/전쟁',
#  10581: '드라마',
#  10582: '드라마',
#  10583: '액션/스릴러/범죄',
#  10584: '드라마',
#  10585: '뮤지컬',
#  10586: '드라마',
#  10587: '드라마',
#  10588: '드라마',
#  10589: '멜로/로맨스/드라마',
#  10590: '드라마/코미디/전쟁',
#  10591: '드라마',
#  10592: '드라마/뮤지컬/가족',
#  10593: '멜로/로맨스/드라마/전쟁',
#  10594: '드라마',
#  10595: '드라마',
#  10596: '판타지/스릴러/공포/미스터리',
#  10597: '드라마/전쟁',
#  10598: '드라마',
#  10599: '멜로/로맨스/범죄',
#  10600: '판타지/드라마/코미디',
#  10601: '멜로/로맨스/드라마/코미디',
#  10602: '멜로/로맨스/코미디',
#  10603: '판타지/SF',
#  10604: '드라마/코미디',
#  10605: '멜로/로맨스/드라마/서부',
#  10606: '멜로/로맨스/드라마',
#  10607: '드라마',
#  10608: '드라마',
#  10609: '드라마/액션/모험',
#  10610: 'SF/코미디',
#  10611: '드라마/모험',
#  10612: '모험',
#  10613: '모험/코미디',
#  10614: '드라마/액션',
#  10615: '드라마/뮤지컬/코미디',
#  10616: '드라마/전쟁',
#  10617: '드라마/멜로/로맨스/모험/가족',
#  10618: '드라마/전쟁',
#  10619: '판타지/액션/모험/코미디',
#  10620: '드라마/액션/스릴러/범죄',
#  10621: '스릴러/미스터리',
#  10622: '액션/미스터리/범죄',
#  10623: '드라마',
#  10624: '드라마',
#  10625: '뮤지컬/코미디',
#  10626: '액션/느와르/범죄/드라마/전쟁',
#  10627: '액션/공포',
#  10628: '드라마',
#  10629: '드라마',
#  10630: '드라마/전쟁',
#  10631: '드라마/코미디/범죄',
#  10632: 'SF/액션',
#  10633: '뮤지컬/코미디/공포',
#  10634: '액션/범죄',
#  10635: '드라마',
#  10636: '드라마/전쟁',
#  10637: '드라마/전쟁',
#  10638: '코미디',
#  10639: '멜로/로맨스/코미디',
#  10640: '드라마/스릴러/범죄',
#  10641: '공포',
#  10642: 'SF/모험/스릴러',
#  10643: '뮤지컬/범죄',
#  10644: '멜로/로맨스/모험/코미디',
#  10645: 'SF/액션/코미디',
#  10646: '드라마',
#  10647: '드라마/전쟁',
#  10648: '액션/모험',
#  10649: nan,
#  10650: '스릴러/공포',
#  10651: '액션/서부',
#  10652: '멜로/로맨스/드라마',
#  10653: '판타지/SF/모험',
#  10654: 'SF/액션/미스터리/스릴러',
#  10655: '드라마/뮤지컬',
#  10656: '멜로/로맨스/코미디',
#  10657: '드라마/스릴러',
#  10658: '멜로/로맨스/코미디',
#  10659: '멜로/로맨스/드라마',
#  10660: '뮤지컬/멜로/로맨스/가족/코미디',
#  10661: '멜로/로맨스',
#  10662: '코미디',
#  10663: '멜로/로맨스/액션',
#  10664: 'SF/액션/스릴러',
#  10665: '드라마',
#  10666: '스릴러/코미디/공포',
#  10667: nan,
#  10668: '드라마/코미디',
#  10669: '멜로/로맨스/애니메이션/코미디/판타지/뮤지컬/모험/가족',
#  10670: '판타지/멜로/로맨스/액션/공포',
#  10671: '멜로/로맨스/액션/스릴러/코미디',
#  10672: nan,
#  10673: '드라마',
#  10674: '공포',
#  10675: '드라마/미스터리',
#  10676: '드라마',
#  10677: '전쟁',
#  10678: '드라마/코미디',
#  10679: '멜로/로맨스/드라마/스릴러/범죄',
#  10680: '드라마',
#  10681: '코미디',
#  10682: '코미디',
#  10683: '멜로/로맨스/드라마/스릴러/전쟁',
#  10684: 'SF/드라마',
#  10685: '멜로/로맨스/드라마/코미디',
#  10686: '판타지/멜로/로맨스/공포',
#  10687: '드라마/스릴러/미스터리/범죄',
#  10688: '드라마',
#  10689: '멜로/로맨스/드라마',
#  10690: '판타지/코미디',
#  10691: 'SF/스릴러/범죄',
#  10692: '드라마',
#  10693: 'SF/액션/모험/코미디',
#  10694: 'SF/스릴러',
#  10695: '드라마/범죄',
#  10696: '드라마/액션/스릴러',
#  10697: '드라마',
#  10698: '멜로/로맨스/드라마/스릴러',
#  10699: '드라마',
#  10700: '액션/스릴러',
#  10701: '멜로/로맨스/드라마',
#  10702: '드라마',
#  10703: '드라마',
#  10704: '드라마/전쟁',
#  10705: '드라마/스릴러/미스터리',
#  10706: '멜로/로맨스/드라마/코미디',
#  10707: nan,
#  10708: '드라마/모험/스릴러',
#  10709: '모험',
#  10710: '드라마',
#  10711: 'SF/드라마',
#  10712: '멜로/로맨스/드라마/에로',
#  10713: '에로',
#  10714: '에로',
#  10715: '공포',
#  10716: '드라마/뮤지컬',
#  10717: '스릴러/코미디',
#  10718: '드라마/범죄',
#  10719: '드라마/스릴러',
#  10720: '드라마/가족',
#  10721: '액션/스릴러/범죄',
#  10722: '액션/스릴러/미스터리/범죄',
#  10723: '드라마/액션/스릴러/범죄',
#  10724: '드라마/액션/스릴러/범죄',
#  10725: '액션/스릴러/범죄',
#  10726: '액션/코미디/범죄/스릴러/드라마',
#  10727: '액션/코미디/범죄/스릴러/드라마',
#  10728: '드라마',
#  10729: '드라마',
#  10730: '애니메이션/판타지/모험/가족/드라마',
#  10731: '코미디',
#  10732: '코미디',
#  10733: '드라마',
#  10734: '서부',
#  10735: '스릴러/공포',
#  10736: '스릴러/공포',
#  10737: '스릴러/공포',
#  10738: '스릴러/공포',
#  10739: '스릴러/공포',
#  10740: '드라마/스릴러/미스터리/범죄',
#  10741: '멜로/로맨스/드라마',
#  10742: '드라마/미스터리/스릴러',
#  10743: '드라마',
#  10744: '판타지/드라마/모험',
#  10745: '드라마',
#  10746: '액션/코미디',
#  10747: '멜로/로맨스/에로',
#  10748: '드라마',
#  10749: 'SF/액션/코미디',
#  10750: '드라마/스릴러',
#  10751: '멜로/로맨스/모험',
#  10752: '뮤지컬/미스터리/코미디/범죄',
#  10753: 'SF/공포',
#  10754: '드라마/스릴러/범죄',
#  10755: '코미디',
#  10756: '코미디',
#  10757: '드라마',
#  10758: '드라마',
#  10759: '드라마/뮤지컬',
#  10760: '코미디',
#  10761: '느와르/스릴러',
#  10762: '드라마',
#  10763: '액션/코미디',
#  10764: '멜로/로맨스/드라마',
#  10765: '드라마/전쟁',
#  10766: '코미디',
#  10767: '드라마',
#  10768: '드라마/전쟁',
#  10769: '드라마/모험',
#  10770: '드라마',
#  10771: '멜로/로맨스/드라마',
#  10772: '다큐멘터리',
#  10773: '코미디',
#  10774: '멜로/로맨스/느와르/미스터리/범죄',
#  10775: '멜로/로맨스/드라마/코미디',
#  10776: '드라마/코미디',
#  10777: '드라마',
#  10778: '드라마',
#  10779: '액션/모험/코미디/미스터리',
#  10780: nan,
#  10781: '코미디/SF/모험/가족',
#  10782: '드라마',
#  10783: '서부',
#  10784: '스릴러',
#  10785: '드라마/서부',
#  10786: '멜로/로맨스/스릴러/전쟁',
#  10787: '드라마',
#  10788: '액션',
#  10789: '드라마/가족',
#  10790: nan,
#  10791: '액션/모험',
#  10792: '판타지/SF/코미디',
#  10793: nan,
#  10794: '멜로/로맨스/드라마/모험',
#  10795: '스릴러/범죄',
#  10796: '드라마',
#  10797: '코미디',
#  10798: nan,
#  10799: '드라마/가족',
#  10800: 'SF/액션',
#  10801: '코미디',
#  10802: '드라마',
#  10803: '드라마/스릴러/범죄',
#  10804: '드라마',
#  10805: '애니메이션/모험/가족',
#  10806: '드라마',
#  10807: '드라마/코미디',
#  10808: '액션/모험',
#  10809: '코미디',
#  10810: nan,
#  10811: '드라마',
#  10812: '가족/코미디',
#  10813: '멜로/로맨스/드라마',
#  10814: '드라마/액션',
#  10815: '드라마/액션',
#  10816: '전쟁',
#  10817: '멜로/로맨스/액션/코미디/범죄/스릴러',
#  10818: '멜로/로맨스/드라마',
#  10819: '액션',
#  10820: '드라마',
#  10821: '미스터리/범죄/공포',
#  10822: '드라마/모험',
#  10823: '드라마/모험',
#  10824: '드라마/모험',
#  10825: '드라마/전쟁',
#  10826: '코미디',
#  10827: '코미디',
#  10828: '가족/모험/코미디',
#  10829: '드라마/미스터리/느와르',
#  10830: '미스터리/스릴러',
#  10831: 'SF/공포',
#  10832: '드라마',
#  10833: '드라마',
#  10834: '드라마',
#  10835: '멜로/로맨스/드라마',
#  10836: '서부',
#  10837: '드라마',
#  10838: '드라마/코미디',
#  10839: '미스터리',
#  10840: '드라마',
#  10841: '드라마',
#  10842: '드라마/코미디',
#  10843: '드라마',
#  10844: '멜로/로맨스/판타지/드라마/공포',
#  10845: nan,
#  10846: '전쟁',
#  10847: '드라마',
#  10848: '액션/모험',
#  10849: '액션/모험',
#  10850: '드라마',
#  10851: '액션/범죄',
#  10852: '드라마/액션',
#  10853: '코미디/범죄',
#  10854: '스릴러/공포',
#  10855: 'SF/코미디',
#  10856: '드라마/액션',
#  10857: '드라마',
#  10858: '드라마',
#  10859: '드라마',
#  10860: '드라마/가족',
#  10861: '멜로/로맨스/드라마',
#  10862: '코미디',
#  10863: '모험/코미디',
#  10864: '코미디/범죄',
#  10865: '드라마',
#  10866: '멜로/로맨스/코미디',
#  10867: '드라마',
#  10868: '코미디',
#  10869: '액션',
#  10870: '액션/모험',
#  10871: '드라마/스릴러/공포/미스터리',
#  10872: '드라마/모험',
#  10873: '드라마/액션/전쟁',
#  10874: '멜로/로맨스/판타지/드라마',
#  10875: '드라마/전쟁',
#  10876: '드라마',
#  10877: '드라마/액션/범죄',
#  10878: '액션/범죄',
#  10879: '드라마/서부',
#  10880: '드라마/에로',
#  10881: '드라마/코미디',
#  10882: '드라마/스릴러/전쟁',
#  10883: '전쟁',
#  10884: '액션/스릴러/코미디/범죄',
#  10885: '멜로/로맨스/드라마',
#  10886: '코미디',
#  10887: '드라마',
#  10888: '액션/스릴러/범죄',
#  10889: '드라마/액션/스릴러/범죄',
#  10890: '드라마',
#  10891: '드라마',
#  10892: '드라마',
#  10893: 'SF/미스터리/공포',
#  10894: '드라마',
#  10895: '코미디',
#  10896: '드라마',
#  10897: '멜로/로맨스/뮤지컬',
#  10898: '미스터리/범죄',
#  10899: '드라마',
#  10900: '코미디',
#  10901: '드라마',
#  10902: '드라마',
#  10903: '드라마',
#  10904: '드라마',
#  10905: '코미디',
#  10906: nan,
#  10907: '드라마/코미디',
#  10908: '액션',
#  10909: '드라마/스릴러/공포',
#  10910: nan,
#  10911: '드라마/미스터리/공포/전쟁',
#  10912: '코미디/판타지/SF/가족',
#  10913: '전쟁',
#  10914: '멜로/로맨스/드라마',
#  10915: '모험',
#  10916: '코미디/범죄',
#  10917: '스릴러',
#  10918: '뮤지컬',
#  10919: '드라마/스릴러',
#  10920: '멜로/로맨스/드라마',
#  10921: '드라마',
#  10922: '드라마',
#  10923: '드라마',
#  10924: '뮤지컬/코미디',
#  10925: '액션/코미디/전쟁',
#  10926: '드라마',
#  10927: '다큐멘터리',
#  10928: '느와르',
#  10929: '드라마/코미디',
#  10930: '코미디',
#  10931: '판타지/액션/모험',
#  10932: '드라마/코미디',
#  10933: '드라마',
#  10934: '드라마',
#  10935: '드라마/액션',
#  10936: '판타지/멜로/로맨스',
#  10937: '드라마',
#  10938: '멜로/로맨스/판타지/드라마/코미디',
#  10939: '코미디',
#  10940: '드라마',
#  10941: '액션/애니메이션/코미디/판타지/가족/범죄',
#  10942: '드라마/모험/전쟁',
#  10943: '판타지',
#  10944: '멜로/로맨스/코미디',
#  10945: '멜로/로맨스/드라마/미스터리/느와르',
#  10946: '드라마',
#  10947: '드라마/뮤지컬',
#  10948: '드라마/미스터리/범죄',
#  10949: '드라마/스릴러',
#  10950: 'SF/액션/전쟁',
#  10951: '코미디/범죄',
#  10952: '액션/범죄',
#  10953: '공포',
#  10954: '멜로/로맨스/드라마',
#  10955: '드라마',
#  10956: '드라마',
#  10957: nan,
#  10958: '드라마/코미디',
#  10959: '코미디',
#  10960: '서부/코미디',
#  10961: '멜로/로맨스/코미디',
#  10962: 'SF/액션/드라마',
#  10963: nan,
#  10964: '드라마',
#  10965: '멜로/로맨스/액션/코미디/모험/범죄/스릴러',
#  10966: '스릴러/공포',
#  10967: '공포',
#  10968: '공포',
#  10969: '공포',
#  10970: '느와르/액션',
#  10971: '액션/스릴러',
#  10972: '액션',
#  10973: '스릴러/공포',
#  10974: nan,
#  10975: 'SF/모험',
#  10976: '드라마',
#  10977: '서부',
#  10978: '드라마/코미디',
#  10979: '뮤지컬/코미디',
#  10980: '드라마',
#  10981: '드라마',
#  10982: '다큐멘터리',
#  10983: '멜로/로맨스/드라마',
#  10984: '드라마/액션',
#  10985: '액션',
#  10986: '드라마/코미디',
#  10987: '드라마/멜로/로맨스/코미디',
#  10988: '드라마',
#  10989: '멜로/로맨스/드라마/코미디',
#  10990: nan,
#  10991: 'SF/드라마',
#  10992: '뮤지컬/코미디',
#  10993: '서부',
#  10994: '멜로/로맨스/드라마/코미디',
#  10995: '스릴러',
#  10996: '코미디',
#  10997: '공포',
#  10998: '드라마/액션/모험/스릴러',
#  10999: 'SF/드라마/공포'}

# %%
movies_df['genres'].loc[10001]
# Out:
# '드라마/멜로/로맨스'

# %% [markdown]
# ## Dataset Loader

# %%
class DatasetLoader:
    def __init__(self, data_path):
        self.train_df, val_temp_df = read_data(data_path)

        self.min_rating = min(self.train_df.rate)
        self.max_rating = self.train_df.rate.max()

        self.unique_users = self.train_df.user.unique()
        self.num_users = len(self.unique_users)
        self.user_to_index = {original: idx for idx, original in enumerate(self.unique_users)}
        # 0 1 0 0 0 ... 0

        self.unique_movies = self.train_df.movie.unique()
        self.num_movies = len(self.unique_movies)
        self.movie_to_index = {original: idx for idx, original in enumerate(self.unique_movies)}

        self.val_df = val_temp_df[val_temp_df.user.isin(self.unique_users) & val_temp_df.movie.isin(self.unique_movies)]

    def generate_trainset(self):
        # user 0, 0, 0, 1,2, 3,3, -> movie: 0,0,0,0,0,0,
        X_train = pd.DataFrame({'user': self.train_df.user.map(self.user_to_index),
                     'movie': self.train_df.movie.map(self.movie_to_index)})
        y_train = self.train_df['rate'].astype(np.float32)

        return X_train, y_train

    def generate_valset(self):
        X_val = pd.DataFrame({'user': self.val_df.user.map(self.user_to_index),
                              'movie': self.val_df.movie.map(self.movie_to_index)})
        y_val = self.val_df['rate'].astype(np.float32)
        return X_val, y_val

# %% [markdown]
# ## Model Structure
# - 논문에서 제시한 모델 구조를 그대로 구현하고 영화 데이터로 실습해본다.
# - User Vector는 전체 영화 데이터에서 영화를 평가한 userid를 onehot vector로 나타낸 형태
# - Item Vector는 전체 영화 데이터에 등장하는 영화의 id를 onehot vector로 나타낸 형태

# %%
class FeedForwardEmbedNN(nn.Module):

    def __init__(self, n_users, n_movies, hidden, dropouts, n_factors, embedding_dropout):
        super().__init__()
        self.user_emb = nn.Embedding(n_users, n_factors)
        self.movie_emb = nn.Embedding(n_movies, n_factors)
        self.drop = nn.Dropout(embedding_dropout)
        self.hidden_layers = nn.Sequential(*list(self.generate_layers(n_factors*2, hidden, dropouts)))
        self.fc = nn.Linear(hidden[-1], 1)

    def generate_layers(self, n_factors, hidden, dropouts):
        assert len(dropouts) == len(hidden)

        idx = 0
        while idx < len(hidden):
            if idx == 0:
                yield nn.Linear(n_factors, hidden[idx])
            else:
                yield nn.Linear(hidden[idx-1], hidden[idx])
            yield nn.ReLU()
            yield nn.Dropout(dropouts[idx])

            idx += 1

    def forward(self, users, movies, min_rating=0.5, max_rating=5):
        concat_features = torch.cat([self.user_emb(users), self.movie_emb(movies)], dim=1)
        x = F.relu(self.hidden_layers(concat_features))
        # 0과 1사이의 숫자로 나타낸다
        out = torch.sigmoid(self.fc(x))
        # rating으로 변환한다
        out = (out * (max_rating - min_rating)) + min_rating

        return out

    def predict(self, users, movies):
        # return the score
        output_scores = self.forward(users, movies)
        return output_scores

# %%
class BatchIterator:

    def __init__(self, X, y, batch_size=32, shuffle=True):
        X, y = np.asarray(X), np.asarray(y)

        if shuffle:
            index = np.random.permutation(X.shape[0])
            X, y = X[index], y[index]

        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.n_batches = int(math.ceil(X.shape[0] // batch_size))
        self._current = 0

    def __iter__(self):
        return self

    def __next__(self):
        return self.next()

    def next(self):
        if self._current >= self.n_batches:
            raise StopIteration()
        k = self._current
        self._current += 1
        bs = self.batch_size
        return self.X[k * bs:(k + 1) * bs], self.y[k * bs:(k + 1) * bs]

# %%
def batches(X, y, bs=32, shuffle=True):
    for x_batch, y_batch in BatchIterator(X, y, bs, shuffle):
        x_batch = torch.LongTensor(x_batch)
        y_batch = torch.FloatTensor(y_batch)
        yield x_batch, y_batch.view(-1, 1)

# %% [markdown]
# ## Train model
# 데이터셋과 모델 학습에 필요한 configuration을 입력하고, 학습을 하는 함수를 만든다
# configuration을 바꾸면서 모델의 성능을 측정해볼 수 있다.

# %%
def model_train(ds, config):
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

    X_train, y_train = ds.generate_trainset()
    X_valid, y_valid = ds.generate_valset()
    print(f'TrainSet Info: {ds.num_users} users, {ds.num_movies} movies')

    model = FeedForwardEmbedNN(
        n_users=ds.num_users, n_movies=ds.num_movies,
        n_factors=config['num_factors'], hidden=config['hidden_layers'],
        embedding_dropout=config['embedding_dropout'], dropouts=config['dropouts']
    )
    model.to(device)

    batch_size = config['batch_size']
    num_epochs = config['num_epochs']
    max_patience = config['total_patience']
    num_patience = 0
    best_loss = np.inf

    criterion = nn.MSELoss(reduction='sum')
    criterion.to(device)
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=config['weight_decay'])

    result = dict()
    for epoch in tqdm(range(num_epochs)):
        training_loss = 0.0
        for batch in batches(X_train, y_train, shuffle=True, bs=batch_size):
            x_batch, y_batch = [b.to(device) for b in batch]
            optimizer.zero_grad()
            # with torch.no_grad() 와 동일한 syntax 입니다
            with torch.set_grad_enabled(True):
                outputs = model(x_batch[:, 0], x_batch[:, 1], ds.min_rating, ds.max_rating)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()
            training_loss += loss.item()
        result['train'] = training_loss / len(X_train)

        # Apply Early Stopping criteria and save best model params
        val_outputs = model(torch.LongTensor(X_valid.user.values).to(device),
                            torch.LongTensor(X_valid.movie.values).to(device), ds.min_rating, ds.max_rating)
        val_loss = criterion(val_outputs.to(device), torch.FloatTensor(y_valid.values).view(-1, 1).to(device))
        result['val'] = float((val_loss / len(X_valid)).data)

        if val_loss < best_loss:
            print('Save new model on epoch: %d' % (epoch + 1))
            best_loss = val_loss
            result['best_loss'] = val_loss
            torch.save(model.state_dict(), config['save_path'])
            num_patience = 0
        else:
            num_patience += 1

        print(f'[epoch: {epoch+1}] train: {result["train"]} - val: {result["val"]}')

        if num_patience >= max_patience:
            print(f"Early Stopped after epoch {epoch+1}")
            break

    return result

# %%
def model_valid(user_id_list, movie_id_list, data_path):
    dataset = DatasetLoader(data_path)
    processed_test_input_df = pd.DataFrame({
        'user_id': [dataset.user_to_index[x] for x in user_id_list],
        'movie_id': [dataset.movie_to_index[x] for x in movie_id_list]
    })

    # 학습한 모델 load하기 
    my_model = FeedForwardEmbedNN(dataset.num_users, dataset.num_movies,
                       config['hidden_layers'], config['dropouts'], config['num_factors'], config['embedding_dropout'])
    my_model.load_state_dict(torch.load('params.data'))
    prediction_outputs = my_model.predict(users=torch.LongTensor(processed_test_input_df.user_id.values),
                     movies=torch.LongTensor(processed_test_input_df.movie_id.values))

    return prediction_outputs

# %%
dataset = DatasetLoader(data_path)

# %%
config = {
  "num_factors": 16,
  "hidden_layers": [64, 32, 16],
  "embedding_dropout": 0.05,
  "dropouts": [0.3, 0.3, 0.3],
  "learning_rate": 1e-3,
  "weight_decay": 1e-5,
  "batch_size": 8,
  "num_epochs": 3,
  "total_patience": 30,
  "save_path": "params.data"
}

# %%
model_train(dataset, config)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# TrainSet Info: 44453 users, 597 movies
#   0%|          | 0/3 [01:28<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-7d35247e30ac> in <module>
# ----> 1 model_train(dataset, config)
#
# <ipython-input-78-eb934bce9254> in model_train(ds, config)
#      34                 loss = criterion(outputs, y_batch)
#      35                 loss.backward()
# ---> 36                 optimizer.step()
#      37             training_loss += loss.item()
#      38         result['train'] = training_loss / len(X_train)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
val_df.head()

# %%
movie_id_list = [10253, 10102, 10007]
user_id = 11242
user_id_list = [user_id] * len(movie_id_list)
pred_results = [float(x) for x in model_valid(user_id_list, movie_id_list, data_path)]

result_df = pd.DataFrame({
    'userId': user_id_list,
    'movieId': movie_id_list,
    # 'movieName': [movieName_dict[x] for x in movie_id_list],
    # 'genres': [genres_dict[x] for x in movie_id_list],
    'pred_ratings': pred_results
})

result_df.sort_values(by='pred_ratings', ascending=False)
